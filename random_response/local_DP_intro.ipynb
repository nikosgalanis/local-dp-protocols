# %% [markdown]
# # Local Differential Privacy: Introduction

# %% [markdown]
# In the big-data era, it is important for several factors to collect statistics from the user, in order to offer the best services possible to them. On the other hand, users do not want their privacy to be jeopardized, while seeking personalized services. A modern way to achieve all the demands, is Local Differential Privacy.
#
# In Local DP, there is a significant difference compared to Global DP: there is no trusted curator between the data and the users, as they just want to send their data, while already being anonymized. Thus, an algorithm must perturb the data before sending it to the untrusted curator, who will then transmit them to the analysts. A scheme showing the key differences between local and global DP is the following:

# %%
from IPython.display import Image
Image(filename='../misc/local_vs_global.png')
